# %%
# Jupyter Notebook: gdp_analysis.ipynb

import os
import sys

# Use relative path to add the module directory to the system path
notebook_dir = os.getcwd()  # Get the current working directory, which is the FED directory
module_path = os.path.join(notebook_dir, 'fed')  # Load 'fed' folder
sys.path.append(module_path)  # Add the module path to the system path



from data import load_data, clean_data
from plot_utils import plot_gdp

data = load_data('certian country gdp.csv')


# 2. Clean Data
cleaned_data = clean_data(data)

# 3. Plot GDP data for China 
plot_gdp(cleaned_data, 'China', country_column='country_name', frequency='yearly')

# %%
import os
print(os.getcwd())  # 打印当前工作目录
# Out:
# c:\Users\73631\OneDrive\桌面\ProblemSet\PS1\FED

# %%
print(cleaned_data.columns)
# Out:
# Index(['country_name', 'country_code', 'indicator_name', 'indicator_code',
#        'year', 'gdp'],
#       dtype='object')
